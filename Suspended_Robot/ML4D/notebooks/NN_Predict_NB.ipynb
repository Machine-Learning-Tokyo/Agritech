# %%
import pandas as pd
import numpy as np

from keras.models import Model, clone_model, load_model
# Out:
# Using TensorFlow backend.

# %%
X = np.load("suspended_robot_X_data.npy",allow_pickle=True)
Y = np.load("suspended_robot_Y_data.npy",allow_pickle=True)

# %%
X.shape, Y.shape
# Out:
# ((442368, 10), (442368, 1))

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X,Y,train_size=0.7,test_size=0.3,random_state=100,shuffle=True)

# %%
X_train.shape,Y_train.shape,X_test.shape,Y_test.shape
# Out:
# ((309657, 10), (309657, 1), (132711, 10), (132711, 1))

# %%
model = load_model("_model-00010-0.00083-0.00036.h5")
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W0903 01:15:49.367347 140171012007808 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:541: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# W0903 01:15:49.397099 140171012007808 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4432: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# W0903 01:15:49.465340 140171012007808 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:190: The name tf.get_default_session is deprecated. Please use tf.compat.v1.get_default_session instead.
#
# ...

# %%
model.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense_9 (Dense)              (None, 100)               1100
# _________________________________________________________________
# dense_10 (Dense)             (None, 50)                5050
# _________________________________________________________________
# dense_11 (Dense)             (None, 5)                 255
# _________________________________________________________________
# dense_12 (Dense)             (None, 1)                 6
# ...
# Total params: 6,411
# Trainable params: 6,411
# Non-trainable params: 0
# _________________________________________________________________

# %%
Y_test_pred = model.predict(X_test)

# %%
from sklearn.metrics import r2_score

# %%
r2_score(Y_test,Y_test_pred)
# Out:
# 0.9996375442313276

# %%
error = Y_test - Y_test_pred

# %%
rss = np.sum(error * error)

# %%
Y_test_avg = np.mean(Y_test)
error = Y_test - Y_test_avg
tss = np.sum(error * error)

# %%
1 - (rss/tss)
# Out:
# 0.9996375442313276

# %%
pd.DataFrame(np.hstack((Y_test,Y_test_pred)),columns=["Actual","Pred"]).head()
# Out:
#      Actual      Pred
# 0 -0.377846 -0.379613
# 1  2.054801  2.091731
# 2 -2.016945 -2.018297
# 3  1.322790  1.308085
# 4 -2.798924 -2.732086

# %%
# Out:
# (132711, 2)
