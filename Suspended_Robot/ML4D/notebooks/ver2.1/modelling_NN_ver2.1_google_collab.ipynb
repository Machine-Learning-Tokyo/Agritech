# %%
import pandas as pd
import numpy as np
import re
import os
from datetime import datetime

import matplotlib.pyplot as plt

from keras.models import Sequential,Model
from keras.layers import Dense
import keras.optimizers as optimizers
from keras.callbacks import ModelCheckpoint
from keras.regularizers import l2
# Out:
# Using TensorFlow backend.

# %%
X = np.load("suspended_robot_X_data.npy",allow_pickle=True)
Y = np.load("suspended_robot_Y_data.npy",allow_pickle=True)

# %%
X.shape, Y.shape
# Out:
# ((110592, 6), (110592, 4))

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X,Y,train_size=0.7,test_size=0.3,random_state=100,shuffle=True)

# %%
X_train.shape,Y_train.shape,X_test.shape,Y_test.shape
# Out:
# ((77414, 6), (77414, 4), (33178, 6), (33178, 4))

# %%
model = Sequential()
model.add(Dense(100,input_dim = X_train.shape[1],activation="relu",kernel_initializer="random_uniform",bias_initializer="zero"))
model.add(Dense(50,activation="relu",kernel_initializer="random_uniform",bias_initializer="zero"))
model.add(Dense(5,activation="relu",kernel_initializer="random_uniform",bias_initializer="zero"))
model.add(Dense(Y_train.shape[1],activation="linear",kernel_initializer="random_uniform",bias_initializer="zero"))

optimizer = optimizers.adam(lr=0.01)
model.compile(optimizer = optimizer,loss="mean_squared_error",metrics=["mse","mae"])
model.summary()
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:66: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:541: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4432: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/optimizers.py:793: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_1 (Dense)              (None, 100)               700
# _________________________________________________________________
# dense_2 (Dense)              (None, 50)                5050
# _________________________________________________________________
# dense_3 (Dense)              (None, 5)                 255
# _________________________________________________________________
# dense_4 (Dense)              (None, 4)                 24
# =================================================================
# Total params: 6,029
# Trainable params: 6,029
# Non-trainable params: 0
# _________________________________________________________________

# %%
from datetime import datetime
curr_date_time = datetime.now()
model_name = "SuspendedBot_" + "_" + str(curr_date_time).replace(' ','').replace(':','_') + '/'
if not os.path.exists(model_name):
    os.mkdir(model_name)
    
filepath = model_name + '_' + 'model-' + '{epoch:05d}-{loss:.5f}-{val_loss:.5f}.h5'
checkpoint = ModelCheckpoint(filepath, monitor='val_loss', verbose=1, save_best_only=True, save_weights_only=False, mode='auto', period=1)
callbacks_list = [checkpoint]

# %%
epoch_len = 10
model_history = model.fit(x=X_train,
          y=Y_train,
          epochs = epoch_len,
          verbose = 1,
          validation_data = (X_test,Y_test),
          batch_size = 100,
          callbacks = callbacks_list)
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:1033: The name tf.assign_add is deprecated. Please use tf.compat.v1.assign_add instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:1020: The name tf.assign is deprecated. Please use tf.compat.v1.assign instead.
#
# Train on 77414 samples, validate on 33178 samples
# Epoch 1/10
# 77414/77414 [==============================] - 2s 20us/step - loss: 0.0784 - mean_squared_error: 0.0784 - mean_absolute_error: 0.1562 - val_loss: 0.0121 - val_mean_squared_error: 0.0121 - val_mean_absolute_error: 0.0829
#
# Epoch 00001: val_loss improved from inf to 0.01211, saving model to SuspendedBot__2019-09-1200_50_58.664594/_model-00001-0.07838-0.01211.h5
# Epoch 2/10
# 77414/77414 [==============================] - 1s 17us/step - loss: 0.0093 - mean_squared_error: 0.0093 - mean_absolute_error: 0.0702 - val_loss: 0.0060 - val_mean_squared_error: 0.0060 - val_mean_absolute_error: 0.0584
#
# Epoch 00002: val_loss improved from 0.01211 to 0.00599, saving model to SuspendedBot__2019-09-1200_50_58.664594/_model-00002-0.00926-0.00599.h5
# Epoch 3/10
# 77414/77414 [==============================] - 1s 17us/step - loss: 0.0039 - mean_squared_error: 0.0039 - mean_absolute_error: 0.0473 - val_loss: 0.0021 - val_mean_squared_error: 0.0021 - val_mean_absolute_error: 0.0351
#
# Epoch 00003: val_loss improved from 0.00599 to 0.00211, saving model to SuspendedBot__2019-09-1200_50_58.664594/_model-00003-0.00394-0.00211.h5
# Epoch 4/10
# 77414/77414 [==============================] - 1s 17us/step - loss: 0.0026 - mean_squared_error: 0.0026 - mean_absolute_error: 0.0387 - val_loss: 0.0016 - val_mean_squared_error: 0.0016 - val_mean_absolute_error: 0.0303
#
# Epoch 00004: val_loss improved from 0.00211 to 0.00157, saving model to SuspendedBot__2019-09-1200_50_58.664594/_model-00004-0.00257-0.00157.h5
# Epoch 5/10
# 77414/77414 [==============================] - 1s 17us/step - loss: 700.6544 - mean_squared_error: 700.6544 - mean_absolute_error: 5.7707 - val_loss: 0.5989 - val_mean_squared_error: 0.5989 - val_mean_absolute_error: 0.6152
#
# Epoch 00005: val_loss did not improve from 0.00157
# Epoch 6/10
# 77414/77414 [==============================] - 1s 17us/step - loss: 0.5699 - mean_squared_error: 0.5699 - mean_absolute_error: 0.5987 - val_loss: 0.5572 - val_mean_squared_error: 0.5572 - val_mean_absolute_error: 0.5877
#
# Epoch 00006: val_loss did not improve from 0.00157
# Epoch 7/10
# 77414/77414 [==============================] - 1s 17us/step - loss: 0.5230 - mean_squared_error: 0.5230 - mean_absolute_error: 0.5681 - val_loss: 0.5316 - val_mean_squared_error: 0.5316 - val_mean_absolute_error: 0.5692
#
# Epoch 00007: val_loss did not improve from 0.00157
# Epoch 8/10
# 77414/77414 [==============================] - 1s 17us/step - loss: 0.4834 - mean_squared_error: 0.4834 - mean_absolute_error: 0.5433 - val_loss: 0.5411 - val_mean_squared_error: 0.5411 - val_mean_absolute_error: 0.5834
#
# Epoch 00008: val_loss did not improve from 0.00157
# Epoch 9/10
# 77414/77414 [==============================] - 1s 17us/step - loss: 0.4438 - mean_squared_error: 0.4438 - mean_absolute_error: 0.5206 - val_loss: 0.5419 - val_mean_squared_error: 0.5419 - val_mean_absolute_error: 0.5888
#
# Epoch 00009: val_loss did not improve from 0.00157
# Epoch 10/10
# 77414/77414 [==============================] - 1s 17us/step - loss: 0.4024 - mean_squared_error: 0.4024 - mean_absolute_error: 0.4967 - val_loss: 0.4506 - val_mean_squared_error: 0.4506 - val_mean_absolute_error: 0.5253
#
# Epoch 00010: val_loss did not improve from 0.00157

# %%
plt.plot(range(0,epoch_len,1),model_history.history["loss"])
plt.plot(range(0,epoch_len,1),model_history.history["val_loss"])
plt.legend(["Train Loss","Val Loss"])
plt.xlabel("Epochs")
plt.ylabel("Loss (%)")
plt.title("Loss Graph")
plt.show()

# %%
print("Minimum Validation Loss = %f achieved at epoch iteration = %d" %(np.array(model_history.history["val_loss"]).min(),np.array(model_history.history["val_loss"]).argmin() + 1))
sel_model_idx = np.array(model_history.history["val_loss"]).argmin() + 1
# Out:
# Minimum Validation Loss = 0.001567 achieved at epoch iteration = 4

# %%
search_string = "model-0*" + str(sel_model_idx) + "-[a-z0-9\-\.]*"
selected_model_name = model_name + list(filter(lambda x: re.search(search_string,x),os.listdir(model_name)))[0]
print("Selected model name : %s" %(selected_model_name))
# Out:
# Selected model name : SuspendedBot__2019-09-1200_50_58.664594/_model-00004-0.00257-0.00157.h5

# %%
from keras.models import clone_model
selected_model = clone_model(model)
selected_model.load_weights(selected_model_name)

# %%
Y_test_pred = selected_model.predict(X_test)

# %%
error0 = Y_test[:,0] - Y_test_pred[:,0]
error1 = Y_test[:,1] - Y_test_pred[:,1]
error2 = Y_test[:,2] - Y_test_pred[:,2]
error3 = Y_test[:,3] - Y_test_pred[:,3]

# %%
import matplotlib.pyplot as plt
fig, ax = plt.subplots(nrows=1,ncols=4,figsize=(20,5),sharex=False,sharey=False)
ax[0].plot(Y_test[:,0],error0,"r+",markersize=1)
ax[1].plot(Y_test[:,1],error1,"r+",markersize=1)
ax[2].plot(Y_test[:,2],error2,"r+",markersize=1)
ax[3].plot(Y_test[:,3],error3,"r+",markersize=1)
plt.show()

# %%
fig, ax = plt.subplots(nrows=1,ncols=4,figsize=(20,5),sharex=False,sharey=False)
ax[0].hist(error0,bins=100)
ax[1].hist(error1,bins=100)
ax[2].hist(error2,bins=100)
ax[3].hist(error3,bins=100)
plt.show()

# %%
import pickle
with open("Y_theta_value_scalar_1X4_format.pkl","rb") as f:
    scalar_obj = pickle.load(f)

# %%
Y_test_unscaled = scalar_obj.inverse_transform(Y_test)
Y_test_pred_unscaled = scalar_obj.inverse_transform(Y_test_pred)

# %%
error_unscaled0 = Y_test_unscaled[:,0] - Y_test_pred_unscaled[:,0]
error_unscaled1 = Y_test_unscaled[:,1] - Y_test_pred_unscaled[:,1]
error_unscaled2 = Y_test_unscaled[:,2] - Y_test_pred_unscaled[:,2]
error_unscaled3 = Y_test_unscaled[:,3] - Y_test_pred_unscaled[:,3]

# %%
fig, ax = plt.subplots(nrows=1,ncols=4,figsize=(20,5),sharex=False,sharey=False)
ax[0].plot(Y_test_unscaled[:,0],error_unscaled0,"r+",markersize=1)
ax[1].plot(Y_test_unscaled[:,1],error_unscaled1,"r+",markersize=1)
ax[2].plot(Y_test_unscaled[:,2],error_unscaled2,"r+",markersize=1)
ax[3].plot(Y_test_unscaled[:,3],error_unscaled3,"r+",markersize=1)
plt.show()

# %%
fig, ax = plt.subplots(nrows=1,ncols=4,figsize=(20,5),sharex=False,sharey=False)
ax[0].hist(error_unscaled0,bins=100)
ax[1].hist(error_unscaled1,bins=100)
ax[2].hist(error_unscaled2,bins=100)
ax[3].hist(error_unscaled3,bins=100)
plt.show()

# %%
from sklearn.metrics import r2_score

# %%
print("Theta0 : Accuracy = %s\n\
Theta1 : Accuracy = %s\n\
Theta2 : Accuracy = %s\n\
Theta3 : Accuracy = %s" %(r2_score(Y_test[:,0],Y_test_pred[:,0]), \
r2_score(Y_test[:,1],Y_test_pred[:,1]), \
r2_score(Y_test[:,2],Y_test_pred[:,2]), \
r2_score(Y_test[:,3],Y_test_pred[:,3])))
# Out:
# Theta0 : Accuracy = 0.9985365833982608
# Theta1 : Accuracy = 0.9972438747902538
# Theta2 : Accuracy = 0.9990460297361413
# Theta3 : Accuracy = 0.9989276451025293

# %%
r2_score(Y_test_unscaled[:,0],Y_test_pred_unscaled[:,0]), \
r2_score(Y_test_unscaled[:,1],Y_test_pred_unscaled[:,1]), \
r2_score(Y_test_unscaled[:,2],Y_test_pred_unscaled[:,2]), \
r2_score(Y_test_unscaled[:,3],Y_test_pred_unscaled[:,3])
# Out:
# (0.9985365835011571,
#  0.9972438753455782,
#  0.9990460300355416,
#  0.9989276453634651)
