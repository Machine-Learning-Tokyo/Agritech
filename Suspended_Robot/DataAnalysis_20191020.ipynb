# %%
import pandas as pd

# %%
data_path="datasets/real/2019-10-18/raw/coords-2019-10-18-20-40-59.txt"

# %%
df = pd.DataFrame()

with open(data_path, 'r') as f:
    for line in f:
        df = pd.concat( [df, pd.DataFrame([tuple(line.strip().split(' '))])], ignore_index=True )

# %%
columns =["command","1","2","3","4","5","6","7","8"]

# %%
df.columns=columns

# %%
df.head()
# Out:
#   command       1      2      3      4      5    6    7    8
# 0       f  79.685  -4857  -5925  -3116  -9975  NaN  NaN  NaN
# 1             NaN    NaN    NaN    NaN    NaN  NaN  NaN  NaN
# 2       f  79.685  -4857  -5925  -3116  -9975  NaN  NaN  NaN
# 3             NaN    NaN    NaN    NaN    NaN  NaN  NaN  NaN
# 4       f  79.685  -4857  -5925  -3116  -9975  NaN  NaN  NaN

# %%
df.columns
# Out:
# Index(['command', '1', '2', '3', '4', '5', '6', '7', '8'], dtype='object')

# %%
f_df = df[df.command=="f"]

# %%
m_df= df[df.command=="m"]

# %%
m_df.head()
# Out:
#     command   1                    2                    3                   4  \
# 214       m  -1  -1048.6762597547424  -1137.0371245723154  1035.8479897419506
# 215       m  -1  -1048.6762597547424  -1137.0371245723154  1035.8479897419506
# 218       m  -1  -1048.6762597547424  -1137.0371245723154  1035.8479897419506
# 219       m  -1  -1048.6762597547424  -1137.0371245723154  1035.8479897419506
# 222       m  -1  -1048.6762597547424  -1137.0371245723154  1035.8479897419506
#
#                       5    6    7    8
# 214  1609.6041510677978  NaN  NaN  NaN
# 215  1609.6041510677978  NaN  NaN  NaN
# 218  1609.6041510677978  NaN  NaN  NaN
# 219  1609.6041510677978  NaN  NaN  NaN
# 222  1609.6041510677978  NaN  NaN  NaN

# %%
columns=list(m_df.columns)

# %%
columns[1]="TS"

# %%
columns
# Out:
# ['command', 'TS', '2', '3', '4', '5', '6', '7', '8']

# %%
m_df.columns=columns

# %%
m_df.drop(labels="command",axis=1,inplace=True)
# Out:
# C:\Users\sezan92\Anaconda3\lib\site-packages\pandas\core\frame.py:3940: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   errors=errors)

# %%
m_df = m_df.astype("float")

# %%
m_df.head()
# Out:
#        1           2            3           4            5   6   7   8
# 214 -1.0 -1048.67626 -1137.037125  1035.84799  1609.604151 NaN NaN NaN
# 215 -1.0 -1048.67626 -1137.037125  1035.84799  1609.604151 NaN NaN NaN
# 218 -1.0 -1048.67626 -1137.037125  1035.84799  1609.604151 NaN NaN NaN
# 219 -1.0 -1048.67626 -1137.037125  1035.84799  1609.604151 NaN NaN NaN
# 222 -1.0 -1048.67626 -1137.037125  1035.84799  1609.604151 NaN NaN NaN

# %%
p_df=df[df.command=="p"]

# %%
p_df.head()
# Out:
#     command      1                   2                      3  \
# 223       p  0.081  0.6142554636828396  -0.048132980325083966
# 224       p  0.153   0.600128016692024    -0.1535951552526949
# 226       p  0.184  0.6006678209588578   -0.14963221859609485
# 227       p  0.214  0.6010342751758302    -0.1486051661164681
# 228       p  0.243  0.6004295401557352    -0.1465971394028194
#
#                         4                   5           6           7  \
# 223  -0.23761772242417836  0.7509404104188294  -80.538089  151.885025
# 224   -0.2354966361214309  0.7488631383637467   -76.42949  143.322715
# 226  -0.23410726905148482  0.7496680932252618  -76.751105  144.132916
# 227  -0.23563637169464935  0.7490991256168973  -76.686928  144.151836
# 228  -0.23938881969412712  0.7487901909079738  -76.753491  144.142473
#
#                8
# 223  -901.142281
# 224  -851.503675
# 226  -856.223373
# 227  -856.208015
# 228   -856.56746

# %%
p_df.drop(labels="command",axis=1,inplace=True)

# %%
p_df.astype("float")
# Out:
#            1         2         3         4         5           6           7  \
# 223    0.081  0.614255 -0.048133 -0.237618  0.750940  -80.538089  151.885025
# 224    0.153  0.600128 -0.153595 -0.235497  0.748863  -76.429490  143.322715
# 226    0.184  0.600668 -0.149632 -0.234107  0.749668  -76.751105  144.132916
# 227    0.214  0.601034 -0.148605 -0.235636  0.749099  -76.686928  144.151836
# 228    0.243  0.600430 -0.146597 -0.239389  0.748790  -76.753491  144.142473
# 232    0.273  0.612456 -0.045004 -0.250765  0.748324  -80.268849  151.459879
# 233    0.302  0.607228 -0.071676 -0.264311  0.745839  -79.374820  149.675450
# 234    0.332  0.600401 -0.148757 -0.235748  0.749542  -76.865396  144.371244
# 235    0.363  0.600378 -0.146836 -0.237615  0.749350  -76.772969  144.315339
# 237    0.395  0.600860 -0.150404 -0.233556  0.749532  -76.826892  144.284244
# 238    0.427  0.601438 -0.152677 -0.230454  0.749569  -77.031637  144.630593
# ...

# %%
m_df.shape
# Out:
# (427, 8)

# %%
p_df.shape
# Out:
# (551, 8)

# %%
p_df.shape

# %%
m_df.shape
